# %%
from utils.polarity import Polarity
from utils.data import Data
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('political_posts.csv')
data = Data(df)
dfs = data.time_series_split()
train_df = dfs[0]
vecs = np.load('models/vector_size_256__max_vocab_size_10000__epochs_50.model.dv.vectors.npy')

# %%
polarity_obj = Polarity(train_df, vecs, standartize_vecs=False)
# Out:
# C:\Users\ntser\Projects\NLP\ba_thesis\political_polarity\utils\polarity.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df['vecs'] = self.vecs.tolist()
# C:\Users\ntser\Projects\NLP\ba_thesis\political_polarity\utils\polarity.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df['vecs'] = self.df['vecs'].apply(lambda x: np.array(x))
# C:\Users\ntser\Projects\NLP\ba_thesis\political_polarity\utils\polarity.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df['date'] = pd.to_datetime(self.df['date'])

# %%
polarity_df = polarity_obj.get_polarity(get_mean=True, get_std=True)
polarity_df.head(10)
# Out:
#         date                            comb  \
# 0 2020-01-31          (imedinews.ge, 1tv.ge)
# 1 2020-01-31  (imedinews.ge, formulanews.ge)
# 2 2020-01-31      (imedinews.ge, mtavari.tv)
# 3 2020-01-31        (1tv.ge, formulanews.ge)
# 4 2020-01-31            (1tv.ge, mtavari.tv)
# 5 2020-01-31    (formulanews.ge, mtavari.tv)
# 6 2020-02-29          (imedinews.ge, 1tv.ge)
# 7 2020-02-29  (imedinews.ge, formulanews.ge)
# 8 2020-02-29      (imedinews.ge, mtavari.tv)
# 9 2020-02-29        (1tv.ge, formulanews.ge)
#
#                                             polarity  polarity_mean  \
# 0                                                0.0       0.000000
# 1  RandomMixture(0.142469 * CompositeDistribution...      -0.015559
# 2  RandomMixture(0.437233 * CompositeDistribution...       0.585024
# 3  RandomMixture(0.0378335 * CompositeDistributio...      -0.006268
# 4  RandomMixture(0.11611 * CompositeDistribution=...       0.204149
# 5                                                0.0       0.000000
# 6                                                0.0       0.000000
# 7  RandomMixture(0.142469 * CompositeDistribution...       0.003858
# 8  RandomMixture(0.437233 * CompositeDistribution...       0.599151
# 9  RandomMixture(0.0378335 * CompositeDistributio...       0.003017
#
#    polarity_std
# 0      0.000000
# 1      0.000078
# 2      0.001598
# 3      0.000005
# 4      0.000109
# 5      0.000000
# 6      0.000000
# 7      0.000046
# 8      0.001046
# 9      0.000003

# %%
polarity_obj.plot_clustered_polarity()
